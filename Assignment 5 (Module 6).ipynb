# %% [markdown]
# # Files, exceptional handling, logging and memory management Questions

# %% [markdown]
# 1) What is the difference between interpreted and compiled languages?
#
# Ans:
#
# Interpreted languages: In interpreted languages, the source code is executed directly by an interpreter, which translates the code line by line into machine code at runtime (e.g., Python).
#
# Compiled languages: In compiled languages, the source code is translated into machine code by a compiler before it is executed. This results in faster execution since the translation happens ahead of time (e.g., C, C++).
#
# 2) What is exception handling in Python?
#
# Ans: Exception handling in Python allows you to handle runtime errors gracefully using the try, except, else, and finally blocks. It ensures that your program doesn't crash unexpectedly and lets you respond to different types of errors in a controlled manner.
#
# 3) What is the purpose of the finally block in exception handling?
#
# Ans: The finally block is used to define cleanup actions that need to be executed regardless of whether an exception occurred or not. This can include closing files, releasing resources, or other necessary actions to maintain system integrity.
#
# 4) What is Logging in Python?
#
# Ans: Logging in Python refers to the use of the logging module, which provides a way to track events that happen during program execution. It helps record runtime information such as errors, warnings, and debugging messages, which can be crucial for troubleshooting.
#
# 5) What is the significance of the __del__ method in Python?
#
# Ans: The __del__ method is a special method in Python that is automatically invoked when an object is about to be destroyed. It allows you to define cleanup operations, such as releasing resources (e.g., closing files or network connections).
#
# 6) What is the difference between import and from ... import in Python?
#
# Ans: import: Imports the entire module, and you need to refer to its components with the module name (e.g., import math and then use math.sqrt()).
# from ... import: Imports specific components from a module, allowing you to use them directly without the module prefix (e.g., from math import sqrt allows direct use of sqrt()).
#
# 7) How can you handle multiple exceptions in Python?
#
# Ans: You can handle multiple exceptions in Python using multiple except blocks, or by specifying a tuple of exceptions in a single except statement (e.g., except (TypeError, ValueError)).
#
# 8) What is the purpose of the with statement when handling files in Python?
#
# Ans: The with statement simplifies resource management by automatically managing file opening and closing. It ensures that files are properly closed after the block of code is executed, even if an error occurs within it.
#
# 9) What is the difference between multithreading and multiprocessing?
#
# Ans: Multithreading: Involves running multiple threads within the same process, which share the same memory space. It is suited for I/O-bound tasks.
#
# Multiprocessing: Involves running multiple processes, each with its own memory space. It is suited for CPU-bound tasks and can utilize multiple cores.
# Advantages of using logging in a program:
#
# 10) What are the advantages of using logging in a program?
#
# Ans: Allows flexibility in outputting messages (to files, console, or remote servers).
# Provides a record of events, which is crucial for production environments.
# Supports different logging levels (e.g., debug, info, error).
#
# 11) What is memory management in Python?
#
# Ans: Python's memory management system automatically handles memory allocation and deallocation. It uses reference counting and a garbage collection mechanism to reclaim unused memory. The Python memory manager oversees memory pools for efficient allocation.
#
# 12) What are the basic steps involved in exception handling in Python?
#
# Ans:Try block: Execute code that may raise an exception.
#
# Except block: Handle exceptions that occur in the try block.
#
# Else block: Execute code if no exception occurred in the try block.
#
# Finally block: Execute cleanup code regardless of whether an exception occurred.
#
# 13) Why is memory management important in Python?
#
# Ans: Memory management ensures that Python programs are efficient and free of memory leaks. It helps in optimizing resource usage and prevents excessive memory consumption, which can cause performance issues or crashes.
#
# 14) What is the role of try and except in exception handling?
#
# Ans: The try block contains code that might throw an exception. If an exception is raised, the except block catches and handles it. This allows the program to continue running rather than crashing.
#
# 15) How does Python's garbage collection system work?
#
# Ans: Python uses automatic memory management, including garbage collection. The garbage collector identifies and reclaims memory used by objects that are no longer referenced, primarily using reference counting and a cyclic garbage collector to clean up circular references.
#
# 16) What is the purpose of the else block in exception handling?
#  Ans: The else block runs if no exception was raised in the try block. It is typically used for code that should only execute when the try block completes successfully.
#
# 17) What are the common logging levels in Python?
#
# Ans:
#
# DEBUG: Detailed information for diagnosing problems.
# INFO: General information about program execution.
# WARNING: Indication that something unexpected happened, but the program is still running.
# ERROR: A more serious problem that prevented part of the program from running.
# CRITICAL: A severe error that may cause the program to terminate.
#
# 18) What is the difference between os.fork() and multiprocessing in Python?
#
# Ans: os.fork() creates a new child process that shares the same memory space with the parent process, which can be useful for low-level tasks but can lead to issues with the Global Interpreter Lock (GIL).
# multiprocessing creates independent processes that run in parallel and do not share memory, allowing full utilization of multiple CPU cores.
#
# 19) What is the importance of closing a file in Python?
#
# Ans: Closing a file ensures that all data is properly written, and resources such as file handles are released. Failure to close files may result in data corruption or resource leakage.
#
# 20) What is the difference between file.read() and file.readline() in Python?
#
# Ans: file.read() reads the entire file content at once as a string.
# file.readline() reads a single line at a time from the file, returning a string containing that line.
#
# 21) What is the logging module in Python used for?
#
# Ans: The logging module in Python is used to log messages, which helps in tracking events, errors, and information during the execution of the program. This is essential for debugging, monitoring, and maintaining large applications. It supports different log levels (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL) and allows you to log to different destinations (e.g., console, files, remote servers).
#
# Key features:
#
# Log levels: DEBUG, INFO, WARNING, ERROR, CRITICAL.
# Flexibility: Can log to different outputs (files, consoles, email, etc.).
# Configuration: You can set up custom loggers, handlers, and formatters.
#
# 22) What is the os module in Python used for in file handling?
#
# Ans: The os module in Python provides a way to interact with the operating system, allowing you to perform operations like file and directory manipulation, and access environment variables. In file handling, it allows you to:
#
# Create, delete, and rename files or directories.
# Navigate directories.
# Check the existence of files or directories.
# Obtain file and directory properties (e.g., size, creation time, permissions).
# Work with file paths and extensions.
#
# 23) What are the challenges associated with memory management in Python?
#
# Ans: Memory management in Python is handled by the Python memory manager, but challenges still exist:
#
# Garbage Collection: Python uses automatic garbage collection to manage memory. It frees memory by destroying unused objects. However, cyclic references (when two or more objects reference each other) can prevent this.
# Memory Leaks: Although Python manages memory automatically, memory leaks can occur if objects are inadvertently retained in memory (e.g., via lingering references or large data structures).
# Global Interpreter Lock (GIL): The GIL in Python can limit multi-threading for CPU-bound tasks, meaning that while Python can handle multiple threads for I/O-bound tasks efficiently, CPU-bound tasks may not benefit much from multiple threads.
# Large Objects: Working with large datasets or objects in memory can increase memory consumption, making it crucial to manage memory effectively.
#
# 24) How do you raise an exception manually in Python?
#
# Ans: You can manually raise an exception using the raise keyword. This is useful when you want to trigger an error condition based on custom logic.
#
# raise ExceptionType("Error message")
#
# 25) Why is it important to use multithreading in certain applications?
#
# Ans: Multithreading allows multiple tasks to be executed concurrently within a program. This can lead to significant improvements in performance and responsiveness, especially for I/O-bound operations (e.g., file handling, network requests, user input):
#
# I/O-bound tasks: Multithreading allows the program to perform multiple tasks (like downloading files or waiting for user input) while not blocking the main execution flow. Python threads are ideal for this because they can run concurrently and don't require the GIL for I/O-bound operations.
#
# Improved Responsiveness: In GUI applications, multithreading ensures the user interface remains responsive while performing background tasks.
#
# Better Resource Utilization: On systems with multiple processors or cores, multithreading helps in utilizing resources more efficiently, though Python's GIL limits true parallelism for CPU-bound tasks.

# %% [markdown]
# # Practical Question

# %% [markdown]
# 1) How can you open a file for writing in Python and write a string to it?

# %%
def write_string_to_file(filename, text):
    """Opens a file for writing and writes a string to it.

    Args:
        filename: The name of the file to write to.
        text: The string to write to the file.
    """
    try:
        with open(filename, 'w') as file:
            file.write(text)
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
write_string_to_file("output.txt", "This is the string to be written to the file.")

# %% [markdown]
# 2) Write a Python program to read the contents of a file and print each line?

# %%
def print_file_contents(filename):
    """Reads a file and prints each line.

    Args:
        filename: The name of the file to read.
    """
    try:
        with open(filename, 'r') as file:
            for line in file:
                print(line, end='')  # end='' prevents extra newline
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage (assuming the file 'output.txt' exists from the previous question):
print_file_contents("output.txt")
# Out:
# Error: File 'output.txt' not found.

# %% [markdown]
# 3) How would you handle a case where the file doesn't exist while trying to open it for reading?

# %%
def print_file_contents(filename):
    """Reads a file and prints each line, handling file not found errors.

    Args:
        filename: The name of the file to read.
    """
    try:
        with open(filename, 'r') as file:
            for line in file:
                print(line, end='')  # end='' prevents extra newline
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

print_file_contents("nonexistent_file.txt")
# Out:
# Error: File 'nonexistent_file.txt' not found.

# %% [markdown]
# 4) Write a Python script that reads from one file and writes its content to another file

# %%
def copy_file_contents(source_filename, destination_filename):
    """Reads from one file and writes its content to another file.

    Args:
        source_filename: The name of the source file.
        destination_filename: The name of the destination file.
    """
    try:
        with open(source_filename, 'r') as source_file:
            with open(destination_filename, 'w') as destination_file:
                for line in source_file:
                    destination_file.write(line)
    except FileNotFoundError:
        print(f"Error: Source file '{source_filename}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage:
copy_file_contents("source.txt", "destination.txt")
# Out:
# Error: Source file 'source.txt' not found.

# %% [markdown]
# 5) How would you catch and handle division by zero error in Python?

# %%
def safe_division(numerator, denominator):
    """Performs division, handling potential ZeroDivisionError.

    Args:
        numerator: The numerator.
        denominator: The denominator.

    Returns:
        The result of the division, or None if a ZeroDivisionError occurs.
    """
    try:
        result = numerator / denominator
        return result
    except ZeroDivisionError:
        print("Error: Division by zero.")
        return None

# Example usage
print(safe_division(10, 2))  # Output: 5.0
print(safe_division(5, 0))   # Output: Error: Division by zero. \n None
# Out:
# 5.0
# Error: Division by zero.
# None

# %% [markdown]
# 6) Write a Python program that logs an error message to a log file when a division by zero exception occurs?

# %%
import logging

def safe_division(numerator, denominator):
    """Performs division, handling potential ZeroDivisionError and logging to a file.

    Args:
        numerator: The numerator.
        denominator: The denominator.

    Returns:
        The result of the division, or None if a ZeroDivisionError occurs.
    """
    # Configure logging
    logging.basicConfig(filename='error.log', level=logging.ERROR,
                        format='%(asctime)s - %(levelname)s - %(message)s')

    try:
        result = numerator / denominator
        return result
    except ZeroDivisionError:
        logging.exception("Division by zero occurred.")  # Log the exception
        return None

# Example usage
print(safe_division(10, 2))  # Output: 5.0
print(safe_division(5, 0))   # Output: None (and logs the error)
# Out:
# ERROR:root:Division by zero occurred.
# Traceback (most recent call last):
#   File "<ipython-input-6-e7fb6b4e476c>", line 18, in safe_division
#     result = numerator / denominator
# ZeroDivisionError: division by zero
# 5.0
# None

# %% [markdown]
# 7) How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %%
import logging

def log_example():
    # Configure the logging system
    logging.basicConfig(filename='my_log_file.log', level=logging.DEBUG,
                        format='%(asctime)s - %(levelname)s - %(message)s')

    # Log messages at different levels
    logging.debug('This is a debug message.')
    logging.info('This is an info message.')
    logging.warning('This is a warning message.')
    logging.error('This is an error message.')
    logging.critical('This is a critical message.')

log_example()
# Out:
# WARNING:root:This is a warning message.
# ERROR:root:This is an error message.
# CRITICAL:root:This is a critical message.

# %% [markdown]
# 8) Write a program to handle a file opening error using exception handling?

# %%
def handle_file_opening_error(filename):
    """Handles file opening errors using exception handling.

    Args:
        filename: The name of the file to open.
    """
    try:
        with open(filename, 'r') as file:
            # Process the file here
            contents = file.read()
            print("File contents:\n", contents)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except PermissionError:
        print(f"Error: Permission denied to access '{filename}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage
handle_file_opening_error("my_file.txt")  # Replace with an actual file or non-existent file
# Out:
# Error: File 'my_file.txt' not found.

# %% [markdown]
# 9) How can you read a file line by line and store its content in a list in Python?

# %%
def read_file_into_list(filename):
    """Reads a file line by line and stores its content in a list.

    Args:
        filename: The name of the file to read.

    Returns:
        A list of strings, where each string is a line from the file.
        Returns an empty list if the file is not found or an error occurs.
    """
    try:
        with open(filename, 'r') as file:
            lines = file.readlines()
            return lines
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return []
    except Exception as e:
        print(f"An error occurred: {e}")
        return []

# Example usage
file_content = read_file_into_list("your_file.txt") #replace your_file.txt

if file_content:
    file_content
# Out:
# Error: File 'your_file.txt' not found.

# %% [markdown]
# 10)  How can you append data to an existing file in Python?

# %%
def append_to_file(filename, text):
    """Appends data to an existing file.

    Args:
        filename: The name of the file.
        text: The text to append.
    """
    try:
        with open(filename, 'a') as file:
            file.write(text)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
append_to_file("my_file.txt", "\nThis is appended text.")

# %% [markdown]
# 11) Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't exist?

# %%
def access_dictionary_key(my_dict, key):
    """Accesses a dictionary key, handling KeyError exceptions.

    Args:
        my_dict: The dictionary to access.
        key: The key to look up.

    Returns:
        The value associated with the key, or None if the key is not found.
    """
    try:
        value = my_dict[key]
        return value
    except KeyError:
        print(f"Error: Key '{key}' not found in the dictionary.")
        return None

# Example usage
my_dictionary = {"a": 1, "b": 2, "c": 3}

print(access_dictionary_key(my_dictionary, "b"))  # Output: 2
print(access_dictionary_key(my_dictionary, "d"))  # Output: Error: Key 'd' not found in the dictionary. \n None
# Out:
# 2
# Error: Key 'd' not found in the dictionary.
# None

# %% [markdown]
# 12) Write a program that demonstrates using multiple except blocks to handle different types of exceptions?

# %%
def handle_multiple_exceptions():
    try:
        # Code that might raise different exceptions
        result = 10 / 0  # ZeroDivisionError
        # my_list = [1, 2, 3]
        # print(my_list[5])  # IndexError
        # with open("nonexistent_file.txt", "r") as file:
        #     contents = file.read() #FileNotFoundError
    except ZeroDivisionError:
        print("Error: Division by zero!")
    except IndexError:
        print("Error: List index out of range!")
    except FileNotFoundError:
        print("Error: File not found.")
    except Exception as e:  # Catch any other exception
        print(f"An unexpected error occurred: {e}")

# Example usage
handle_multiple_exceptions()
# Out:
# Error: Division by zero!

# %% [markdown]
# 13) How would you check if a file exists before attempting to read it in Python?

# %%
import os

def read_file_if_exists(filename):
    """Reads a file if it exists, otherwise prints a message.

    Args:
        filename: The name of the file to read.
    """
    if os.path.exists(filename):
        try:
            with open(filename, 'r') as file:
                for line in file:
                    print(line, end='')
        except Exception as e:
            print(f"An error occurred while reading the file: {e}")
    else:
        print(f"Error: File '{filename}' not found.")

# Example usage
read_file_if_exists("my_file.txt")
# Out:
# This is appended text.

# %% [markdown]
#  14) Write a program that uses the logging module to log both informational and error messages?

# %%
import logging

def log_info_and_error():
    # Configure the logging system
    logging.basicConfig(filename='app.log', level=logging.INFO,
                        format='%(asctime)s - %(levelname)s - %(message)s')

    # Log an informational message
    logging.info("This is an informational message.")

    try:
        # Code that might raise an error
        result = 10 / 0
    except ZeroDivisionError:
        # Log an error message
        logging.error("An error occurred: Division by zero.", exc_info=True)

log_info_and_error()
# Out:
# ERROR:root:An error occurred: Division by zero.
# Traceback (most recent call last):
#   File "<ipython-input-20-6ddf2f77382d>", line 13, in log_info_and_error
#     result = 10 / 0
# ZeroDivisionError: division by zero

# %% [markdown]
# 15) Write a Python program that prints the content of a file and handles the case when the file is empty?

# %%
def print_file_content(filename):
    """Prints the content of a file, handling empty files."""
    try:
        with open(filename, 'r') as file:
            content = file.read()
            if not content:
                print(f"The file '{filename}' is empty.")
            else:
                print(content)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
print_file_content("output.txt")  # Replace with your file
# Out:
# This is the string to be written to the file.

# %% [markdown]
# 16)  Demonstrate how to use memory profiling to check the memory usage of a small programF

# %%
# !pip install memory_profiler

import os
from memory_profiler import profile

@profile
def my_memory_intensive_function():
    # Simulate memory usage (replace with your actual code)
    large_list = [i for i in range(1000000)]
    return sum(large_list)

if __name__ == "__main__":
    my_memory_intensive_function()
    # To run memory_profiler, you'll need to use the following command in the terminal or notebook:
    # mprof run your_script_name.py
    # Then, to visualize the memory usage:
    # mprof plot

# %% [markdown]
#  17) Write a Python program to create and write a list of numbers to a file, one number per line?

# %%
def write_numbers_to_file(filename, numbers):
    """Writes a list of numbers to a file, one number per line.

    Args:
        filename: The name of the file to write to.
        numbers: A list of numbers.
    """
    try:
        with open(filename, 'w') as file:
            for number in numbers:
                file.write(str(number) + '\n')
    except Exception as e:
        print(f"An error occurred: {e}")

# Example usage
my_numbers = [1, 2, 3, 4, 5,10,20,30]
write_numbers_to_file("numbers.txt", my_numbers)

# %% [markdown]
# 18) How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %%
import logging
from logging.handlers import RotatingFileHandler
import os

def configure_rotating_log(log_file="my_app.log", max_bytes=1024*1024): # 1MB
    """Configures a rotating log handler."""

    # Create the log directory if it doesn't exist
    log_dir = os.path.dirname(log_file)
    if log_dir and not os.path.exists(log_dir):
        os.makedirs(log_dir)

    # Create a rotating file handler
    handler = RotatingFileHandler(log_file, maxBytes=max_bytes, backupCount=5) # Keep 5 backup files

    # Configure the logging format
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    handler.setFormatter(formatter)

    # Get the root logger and add the handler
    logger = logging.getLogger()  # Get the root logger
    logger.addHandler(handler)
    logger.setLevel(logging.INFO) # Set the desired logging level

    return logger


# Example usage:
logger = configure_rotating_log()

# Log some messages (this will trigger the log rotation)
for i in range(100000): #log enough to exceed 1MB
  logger.info(f"This is a test log message {i}")
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:root:This is a test log message 5920
# INFO:root:This is a test log message 5921
# INFO:root:This is a test log message 5922
# INFO:root:This is a test log message 5923
# INFO:root:This is a test log message 5924
# INFO:root:This is a test log message 5925
# INFO:root:This is a test log message 5926
# INFO:root:This is a test log message 5927
# INFO:root:This is a test log message 5928
# INFO:root:This is a test log message 5929
# INFO:root:This is a test log message 5930
# INFO:root:This is a test log message 5931
# INFO:root:This is a test log message 5932
# INFO:root:This is a test log message 5933
# INFO:root:This is a test log message 5934
# INFO:root:This is a test log message 5935
# INFO:root:This is a test log message 5936
# INFO:root:This is a test log message 5937
# INFO:root:This is a test log message 5938
# INFO:root:This is a test log message 5939
# INFO:root:This is a test log message 5940
# INFO:root:This is a test log message 5941
# INFO:root:This is a test log message 5942
# INFO:root:This is a test log message 5943
# INFO:root:This is a test log message 5944
# INFO:root:This is a test log message 5945
# INFO:root:This is a test log message 5946
# INFO:root:This is a test log message 5947
# INFO:root:This is a test log message 5948
# INFO:root:This is a test log message 5949
# INFO:root:This is a test log message 5950
# INFO:root:This is a test log message 5951
# INFO:root:This is a test log message 5952
# INFO:root:This is a test log message 5953
# INFO:root:This is a test log message 5954
# INFO:root:This is a test log message 5955
# INFO:root:This is a test log message 5956
# INFO:root:This is a test log message 5957
# INFO:root:This is a test log message 5958
# INFO:root:This is a test log message 5959
# INFO:root:This is a test log message 5960
# INFO:root:This is a test log message 5961
# INFO:root:This is a test log message 5962
# INFO:root:This is a test log message 5963
# INFO:root:This is a test log message 5964
# INFO:root:This is a test log message 5965
# INFO:root:This is a test log message 5966
# INFO:root:This is a test log message 5967
# INFO:root:This is a test log message 5968
# INFO:root:This is a test log message 5969
# INFO:root:This is a test log message 5970
# INFO:root:This is a test log message 5971
# INFO:root:This is a test log message 5972
# INFO:root:This is a test log message 5973
# INFO:root:This is a test log message 5974
# INFO:root:This is a test log message 5975
# INFO:root:This is a test log message 5976
# INFO:root:This is a test log message 5977
# INFO:root:This is a test log message 5978
# INFO:root:This is a test log message 5979
# INFO:root:This is a test log message 5980
# INFO:root:This is a test log message 5981
# INFO:root:This is a test log message 5982
# INFO:root:This is a test log message 5983
# INFO:root:This is a test log message 5984
# INFO:root:This is a test log message 5985
# INFO:root:This is a test log message 5986
# INFO:root:This is a test log message 5987
# INFO:root:This is a test log message 5988
# INFO:root:This is a test log message 5989
# INFO:root:This is a test log message 5990
# INFO:root:This is a test log message 5991
# INFO:root:This is a test log message 5992
# INFO:root:This is a test log message 5993
# INFO:root:This is a test log message 5994
# INFO:root:This is a test log message 10564
# INFO:root:This is a test log message 10565
# INFO:root:This is a test log message 10566
# INFO:root:This is a test log message 10567
# INFO:root:This is a test log message 10568
# INFO:root:This is a test log message 10569
# INFO:root:This is a test log message 10570
# INFO:root:This is a test log message 10571
# INFO:root:This is a test log message 10572
# INFO:root:This is a test log message 10573
# INFO:root:This is a test log message 10574
# INFO:root:This is a test log message 10575
# INFO:root:This is a test log message 10576
# INFO:root:This is a test log message 10577
# INFO:root:This is a test log message 10578
# INFO:root:This is a test log message 10579
# INFO:root:This is a test log message 10580
# INFO:root:This is a test log message 10581
# INFO:root:This is a test log message 10582
# INFO:root:This is a test log message 10583
# INFO:root:This is a test log message 10584
# INFO:root:This is a test log message 10585
# INFO:root:This is a test log message 10586
# INFO:root:This is a test log message 10587
# INFO:root:This is a test log message 10588
# INFO:root:This is a test log message 10589
# INFO:root:This is a test log message 10590
# INFO:root:This is a test log message 10591
# INFO:root:This is a test log message 10592
# INFO:root:This is a test log message 10593
# INFO:root:This is a test log message 10594
# INFO:root:This is a test log message 10595
# INFO:root:This is a test log message 10596
# INFO:root:This is a test log message 10597
# INFO:root:This is a test log message 10598
# INFO:root:This is a test log message 10599
# INFO:root:This is a test log message 10600
# INFO:root:This is a test log message 10601
# INFO:root:This is a test log message 10602
# INFO:root:This is a test log message 10603
# INFO:root:This is a test log message 10604
# INFO:root:This is a test log message 10605
# INFO:root:This is a test log message 10606
# INFO:root:This is a test log message 10607
# INFO:root:This is a test log message 10608
# INFO:root:This is a test log message 10609
# INFO:root:This is a test log message 10610
# INFO:root:This is a test log message 10611
# INFO:root:This is a test log message 10612
# INFO:root:This is a test log message 10613
# INFO:root:This is a test log message 10614
# INFO:root:This is a test log message 10615
# INFO:root:This is a test log message 10616
# INFO:root:This is a test log message 10617
# INFO:root:This is a test log message 10618
# INFO:root:This is a test log message 10619
# INFO:root:This is a test log message 10620
# INFO:root:This is a test log message 10621
# INFO:root:This is a test log message 10622
# INFO:root:This is a test log message 10623
# INFO:root:This is a test log message 10624
# INFO:root:This is a test log message 10625
# INFO:root:This is a test log message 10626
# INFO:root:This is a test log message 10627
# INFO:root:This is a test log message 10628
# INFO:root:This is a test log message 10629
# INFO:root:This is a test log message 10630
# INFO:root:This is a test log message 10631
# INFO:root:This is a test log message 10632
# INFO:root:This is a test log message 10633
# INFO:root:This is a test log message 10634
# INFO:root:This is a test log message 10635
# INFO:root:This is a test log message 10636
# INFO:root:This is a test log message 10637
# INFO:root:This is a test log message 10638
# INFO:root:This is a test log message 10639
# INFO:root:This is a test log message 10640
# INFO:root:This is a test log message 10641
# INFO:root:This is a test log message 10642
# INFO:root:This is a test log message 10643
# INFO:root:This is a test log message 10644
# INFO:root:This is a test log message 10645
# INFO:root:This is a test log message 10646
# INFO:root:This is a test log message 10647
# INFO:root:This is a test log message 10648
# INFO:root:This is a test log message 10649
# INFO:root:This is a test log message 10650
# INFO:root:This is a test log message 10651
# INFO:root:This is a test log message 10652
# INFO:root:This is a test log message 10653
# INFO:root:This is a test log message 10654
# INFO:root:This is a test log message 10655
# INFO:root:This is a test log message 10656
# INFO:root:This is a test log message 10657
# INFO:root:This is a test log message 10658
# INFO:root:This is a test log message 10659
# INFO:root:This is a test log message 10660
# INFO:root:This is a test log message 10661
# INFO:root:This is a test log message 10662
# INFO:root:This is a test log message 10663
# INFO:root:This is a test log message 10664
# INFO:root:This is a test log message 10665
# INFO:root:This is a test log message 10666
# INFO:root:This is a test log message 10667
# INFO:root:This is a test log message 10668
# INFO:root:This is a test log message 10669
# INFO:root:This is a test log message 10670
# INFO:root:This is a test log message 10671
# INFO:root:This is a test log message 10672
# INFO:root:This is a test log message 10673
# INFO:root:This is a test log message 10674
# INFO:root:This is a test log message 10675
# INFO:root:This is a test log message 10676
# INFO:root:This is a test log message 10677
# INFO:root:This is a test log message 10678
# INFO:root:This is a test log message 10679
# INFO:root:This is a test log message 10680
# INFO:root:This is a test log message 10681
# INFO:root:This is a test log message 10682
# INFO:root:This is a test log message 10683
# INFO:root:This is a test log message 10684
# INFO:root:This is a test log message 10685
# INFO:root:This is a test log message 10686
# INFO:root:This is a test log message 10687
# INFO:root:This is a test log message 10688
# INFO:root:This is a test log message 10689
# INFO:root:This is a test log message 10690
# INFO:root:This is a test log message 10691
# INFO:root:This is a test log message 10692
# INFO:root:This is a test log message 10693
# INFO:root:This is a test log message 10694
# INFO:root:This is a test log message 10695
# INFO:root:This is a test log message 10696
# INFO:root:This is a test log message 10697
# INFO:root:This is a test log message 10698
# INFO:root:This is a test log message 10699
# INFO:root:This is a test log message 10700
# INFO:root:This is a test log message 10701
# INFO:root:This is a test log message 10702
# INFO:root:This is a test log message 10703
# INFO:root:This is a test log message 10704
# INFO:root:This is a test log message 10705
# INFO:root:This is a test log message 10706
# INFO:root:This is a test log message 10707
# INFO:root:This is a test log message 10708
# INFO:root:This is a test log message 10709
# INFO:root:This is a test log message 10710
# INFO:root:This is a test log message 10711
# INFO:root:This is a test log message 10712
# INFO:root:This is a test log message 10713
# INFO:root:This is a test log message 10714
# INFO:root:This is a test log message 10715
# INFO:root:This is a test log message 10716
# INFO:root:This is a test log message 10717
# INFO:root:This is a test log message 10718
# INFO:root:This is a test log message 10719
# INFO:root:This is a test log message 10720
# INFO:root:This is a test log message 10721
# INFO:root:This is a test log message 10722
# INFO:root:This is a test log message 10723
# INFO:root:This is a test log message 10724
# INFO:root:This is a test log message 10725
# INFO:root:This is a test log message 10726
# INFO:root:This is a test log message 10727
# INFO:root:This is a test log message 10728
# INFO:root:This is a test log message 10729
# INFO:root:This is a test log message 10730
# INFO:root:This is a test log message 10731
# INFO:root:This is a test log message 10732
# INFO:root:This is a test log message 10733
# INFO:root:This is a test log message 10734
# INFO:root:This is a test log message 10735
# INFO:root:This is a test log message 10736
# INFO:root:This is a test log message 10737
# INFO:root:This is a test log message 10738
# INFO:root:This is a test log message 10739
# INFO:root:This is a test log message 10740
# INFO:root:This is a test log message 10741
# INFO:root:This is a test log message 10742
# INFO:root:This is a test log message 10743
# INFO:root:This is a test log message 10744
# INFO:root:This is a test log message 10745
# INFO:root:This is a test log message 10746
# INFO:root:This is a test log message 10747
# INFO:root:This is a test log message 10748
# INFO:root:This is a test log message 10749
# INFO:root:This is a test log message 10750
# INFO:root:This is a test log message 10751
# INFO:root:This is a test log message 10752
# INFO:root:This is a test log message 10753
# INFO:root:This is a test log message 10754
# INFO:root:This is a test log message 10755
# INFO:root:This is a test log message 10756
# INFO:root:This is a test log message 10757
# INFO:root:This is a test log message 10758
# INFO:root:This is a test log message 10759
# INFO:root:This is a test log message 10760
# INFO:root:This is a test log message 10761
# INFO:root:This is a test log message 10762
# INFO:root:This is a test log message 10763
# INFO:root:This is a test log message 10764
# INFO:root:This is a test log message 10765
# INFO:root:This is a test log message 10766
# INFO:root:This is a test log message 10767
# INFO:root:This is a test log message 10768
# INFO:root:This is a test log message 10769
# INFO:root:This is a test log message 10770
# INFO:root:This is a test log message 10771
# INFO:root:This is a test log message 10772
# INFO:root:This is a test log message 10773
# INFO:root:This is a test log message 10774
# INFO:root:This is a test log message 10775
# INFO:root:This is a test log message 10776
# INFO:root:This is a test log message 10777
# INFO:root:This is a test log message 10778
# INFO:root:This is a test log message 10779
# INFO:root:This is a test log message 10780
# INFO:root:This is a test log message 10781
# INFO:root:This is a test log message 10782
# INFO:root:This is a test log message 10783
# INFO:root:This is a test log message 10784
# INFO:root:This is a test log message 10785
# INFO:root:This is a test log message 10786
# INFO:root:This is a test log message 10787
# INFO:root:This is a test log message 10788
# INFO:root:This is a test log message 10789
# INFO:root:This is a test log message 10790
# INFO:root:This is a test log message 10791
# INFO:root:This is a test log message 10792
# INFO:root:This is a test log message 10793
# INFO:root:This is a test log message 10794
# INFO:root:This is a test log message 10795
# INFO:root:This is a test log message 10796
# INFO:root:This is a test log message 10797
# INFO:root:This is a test log message 10798
# INFO:root:This is a test log message 10799
# INFO:root:This is a test log message 10800
# INFO:root:This is a test log message 10801
# INFO:root:This is a test log message 10802
# INFO:root:This is a test log message 10803
# INFO:root:This is a test log message 10804
# INFO:root:This is a test log message 10805
# INFO:root:This is a test log message 10806
# INFO:root:This is a test log message 10807
# INFO:root:This is a test log message 10808
# INFO:root:This is a test log message 10809
# INFO:root:This is a test log message 10810
# INFO:root:This is a test log message 10811
# INFO:root:This is a test log message 10812
# INFO:root:This is a test log message 10813
# INFO:root:This is a test log message 10814
# INFO:root:This is a test log message 10815
# INFO:root:This is a test log message 10816
# INFO:root:This is a test log message 10817
# INFO:root:This is a test log message 10818
# INFO:root:This is a test log message 10819
# INFO:root:This is a test log message 10820
# INFO:root:This is a test log message 10821
# INFO:root:This is a test log message 10822
# INFO:root:This is a test log message 10823
# INFO:root:This is a test log message 10824
# INFO:root:This is a test log message 10825
# INFO:root:This is a test log message 10826
# INFO:root:This is a test log message 10827
# INFO:root:This is a test log message 10828
# INFO:root:This is a test log message 10829
# INFO:root:This is a test log message 10830
# INFO:root:This is a test log message 10831
# INFO:root:This is a test log message 10832
# INFO:root:This is a test log message 10833
# INFO:root:This is a test log message 10834
# INFO:root:This is a test log message 10835
# INFO:root:This is a test log message 10836
# INFO:root:This is a test log message 10837
# INFO:root:This is a test log message 10838
# INFO:root:This is a test log message 10839
# INFO:root:This is a test log message 10840
# INFO:root:This is a test log message 10841
# INFO:root:This is a test log message 10842
# INFO:root:This is a test log message 10843
# INFO:root:This is a test log message 10844
# INFO:root:This is a test log message 10845
# INFO:root:This is a test log message 10846
# INFO:root:This is a test log message 10847
# INFO:root:This is a test log message 10848
# INFO:root:This is a test log message 10849
# INFO:root:This is a test log message 10850
# INFO:root:This is a test log message 10851
# INFO:root:This is a test log message 10852
# INFO:root:This is a test log message 10853
# INFO:root:This is a test log message 10854
# INFO:root:This is a test log message 10855
# INFO:root:This is a test log message 10856
# INFO:root:This is a test log message 10857
# INFO:root:This is a test log message 10858
# INFO:root:This is a test log message 10859
# INFO:root:This is a test log message 10860
# INFO:root:This is a test log message 10861
# INFO:root:This is a test log message 10862
# INFO:root:This is a test log message 10863
# INFO:root:This is a test log message 10864
# INFO:root:This is a test log message 10865
# INFO:root:This is a test log message 10866
# INFO:root:This is a test log message 10867
# INFO:root:This is a test log message 10868
# INFO:root:This is a test log message 10869
# INFO:root:This is a test log message 10870
# INFO:root:This is a test log message 10871
# INFO:root:This is a test log message 10872
# INFO:root:This is a test log message 10873
# INFO:root:This is a test log message 10874
# INFO:root:This is a test log message 10875
# INFO:root:This is a test log message 10876
# INFO:root:This is a test log message 10877
# INFO:root:This is a test log message 10878
# INFO:root:This is a test log message 10879
# INFO:root:This is a test log message 10880
# INFO:root:This is a test log message 10881
# INFO:root:This is a test log message 10882
# INFO:root:This is a test log message 10883
# INFO:root:This is a test log message 10884
# INFO:root:This is a test log message 10885
# INFO:root:This is a test log message 10886
# INFO:root:This is a test log message 10887
# INFO:root:This is a test log message 10888
# INFO:root:This is a test log message 10889
# INFO:root:This is a test log message 10890
# INFO:root:This is a test log message 10891
# INFO:root:This is a test log message 10892
# INFO:root:This is a test log message 10893
# INFO:root:This is a test log message 10894
# INFO:root:This is a test log message 10895
# INFO:root:This is a test log message 10896
# INFO:root:This is a test log message 10897
# INFO:root:This is a test log message 10898
# INFO:root:This is a test log message 10899
# INFO:root:This is a test log message 10900
# INFO:root:This is a test log message 10901
# INFO:root:This is a test log message 10902
# INFO:root:This is a test log message 10903
# INFO:root:This is a test log message 10904
# INFO:root:This is a test log message 10905
# INFO:root:This is a test log message 10906
# INFO:root:This is a test log message 10907
# INFO:root:This is a test log message 10908
# INFO:root:This is a test log message 10909
# INFO:root:This is a test log message 10910
# INFO:root:This is a test log message 10911
# INFO:root:This is a test log message 10912
# INFO:root:This is a test log message 10913
# INFO:root:This is a test log message 10914
# INFO:root:This is a test log message 10915
# INFO:root:This is a test log message 10916
# INFO:root:This is a test log message 10917
# INFO:root:This is a test log message 10918
# INFO:root:This is a test log message 10919

# %% [markdown]
# 19) Write a program that handles both IndexError and KeyError using a try-except block?

# %%
def handle_errors(data_structure, index_or_key):
    """Handles IndexError and KeyError exceptions.

    Args:
        data_structure: A list or dictionary.
        index_or_key: The index (for lists) or key (for dictionaries) to access.
    """
    try:
        if isinstance(data_structure, list):
            value = data_structure[index_or_key]
            print("Value accessed:", value)
        elif isinstance(data_structure, dict):
            value = data_structure[index_or_key]
            print("Value accessed:", value)
        else:
            print("Unsupported data structure type.")
    except IndexError:
        print("Error: Index is out of range.")
    except KeyError:
        print("Error: Key not found in the dictionary.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")


# Example usage:
my_list = [1, 2, 3]
handle_errors(my_list, 2)  # Valid index

handle_errors(my_list, 5)  # Invalid index (IndexError)

my_dict = {"a": 1, "b": 2}
handle_errors(my_dict, "a")  # Valid key

handle_errors(my_dict, "c")  # Invalid key (KeyError)
# Out:
# Value accessed: 3
# Error: Index is out of range.
# Value accessed: 1
# Error: Key not found in the dictionary.

# %% [markdown]
# 20)  How would you open a file and read its contents using a context manager in Python?

# %%
def read_file_with_context_manager(filename):
    """Reads a file's contents using a context manager.

    Args:
        filename: The path to the file.

    Returns:
        The file's contents as a string, or None if an error occurs.
    """
    try:
        with open(filename, 'r') as file:
            contents = file.read()
            return contents
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# %% [markdown]
# 21) Write a Python program that reads a file and prints the number of occurrences of a specific word?

# %%
def count_word_occurrences(filename, word):
    """Reads a file and counts the occurrences of a specific word.

    Args:
        filename: The name of the file to read.
        word: The word to count.

    Returns:
        The number of times the word appears in the file, or -1 if an error occurs.
    """
    try:
        with open(filename, 'r') as file:
            content = file.read()
            words = content.lower().split()  # Convert to lowercase for case-insensitive counting
            return words.count(word.lower())
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found.")
        return -1
    except Exception as e:
        print(f"An error occurred: {e}")
        return -1

# Example usage
filename = "your_file.txt"  # Replace with the actual filename
word_to_count = "example"  # Replace with the word you want to count
occurrences = count_word_occurrences(filename, word_to_count)

if occurrences != -1:
    print(f"The word '{word_to_count}' appears {occurrences} times in the file.")
# Out:
# Error: File 'your_file.txt' not found.

# %% [markdown]
# 22) How can you check if a file is empty before attempting to read its contents?

# %%
import os

def read_file_if_not_empty(filename):
    """Reads a file if it's not empty, otherwise prints a message."""
    if os.path.exists(filename):
        file_size = os.path.getsize(filename)
        if file_size > 0:  # Check if the file size is greater than zero
            try:
                with open(filename, 'r') as file:
                    for line in file:
                        print(line, end='')
            except Exception as e:
                print(f"An error occurred while reading the file: {e}")
        else:
            print(f"The file '{filename}' is empty.")
    else:
        print(f"Error: File '{filename}' not found.")

# Example usage
read_file_if_not_empty("my_file.txt")
# Out:
# This is appended text.

# %% [markdown]
# 23)  Write a Python program that writes to a log file when an error occurs during file handling.

# %%
import logging

def file_operation(filename):
    try:
        with open(filename, 'r') as file:
            contents = file.read()
            # Process file contents here...
    except FileNotFoundError:
        logging.error(f"Error: File '{filename}' not found.")
        # Handle the error appropriately (e.g., create the file, exit the program)
    except PermissionError:
        logging.error(f"Error: Permission denied to access '{filename}'.")
        # Handle permission error
    except Exception as e:
        logging.exception(f"An unexpected error occurred while processing '{filename}': {e}")
        # Log the unexpected error with traceback information

# Configure the logging system to write to a file named 'file_handling.log'
logging.basicConfig(filename='file_handling.log', level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s')

# Example usage (replace with your file operations)
file_operation("my_file.txt")
